# %%
import librosa
import numpy as np
import pandas as pd


'''
    function: extract_features
    input: path to mp3 files
    output: csv file containing features extracted
    
    This function reads the content in a directory and for each mp3 file detected
    reads the file and extracts relevant features using librosa library for audio
    signal processing
'''
def fn_song_features(songname, d = 60):

    feature_set = pd.DataFrame()  # Feature Matrix

    # Individual Feature Vectors
    tempo_vector = pd.Series()
    total_beats = pd.Series()
    average_beats = pd.Series()
    chroma_stft_mean = pd.Series()
    chroma_stft_std = pd.Series()
    chroma_stft_var = pd.Series()
    chroma_cq_mean = pd.Series()
    chroma_cq_std = pd.Series()
    chroma_cq_var = pd.Series()
    chroma_cens_mean = pd.Series()
    chroma_cens_std = pd.Series()
    chroma_cens_var = pd.Series()
    mel_mean = pd.Series()
    mel_std = pd.Series()
    mel_var = pd.Series()
    mfcc_mean = pd.Series()
    mfcc_std = pd.Series()
    mfcc_var = pd.Series()
    mfcc_delta_mean = pd.Series()
    mfcc_delta_std = pd.Series()
    mfcc_delta_var = pd.Series()
    rmse_mean = pd.Series()
    rmse_std = pd.Series()
    rmse_var = pd.Series()
    cent_mean = pd.Series()
    cent_std = pd.Series()
    cent_var = pd.Series()
    spec_bw_mean = pd.Series()
    spec_bw_std = pd.Series()
    spec_bw_var = pd.Series()
    contrast_mean = pd.Series()
    contrast_std = pd.Series()
    contrast_var = pd.Series()
    rolloff_mean = pd.Series()
    rolloff_std = pd.Series()
    rolloff_var = pd.Series()
    poly_mean = pd.Series()
    poly_std = pd.Series()
    poly_var = pd.Series()
    tonnetz_mean = pd.Series()
    tonnetz_std = pd.Series()
    tonnetz_var = pd.Series()
    zcr_mean = pd.Series()
    zcr_std = pd.Series()
    zcr_var = pd.Series()
    harm_mean = pd.Series()
    harm_std = pd.Series()
    harm_var = pd.Series()
    perc_mean = pd.Series()
    perc_std = pd.Series()
    perc_var = pd.Series()
    frame_mean = pd.Series()
    frame_std = pd.Series()
    frame_var = pd.Series()

     # Transforming Features
    y, sr = librosa.load(songname,duration=d)
    S = np.abs(librosa.stft(y))

    id = 1 

    # Extracting Features
    tempo, beats = librosa.beat.beat_track(y=y, sr=sr)
    #print(tempo,beats)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    #print(chroma_stft)
    chroma_cq = librosa.feature.chroma_cqt(y=y, sr=sr)
    #print(chroma_cq)
    chroma_cens = librosa.feature.chroma_cens(y=y, sr=sr)
    melspectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    contrast = librosa.feature.spectral_contrast(S=S, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    poly_features = librosa.feature.poly_features(S=S, sr=sr)
    tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    harmonic = librosa.effects.harmonic(y)
    percussive = librosa.effects.percussive(y)

    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    mfcc_delta = librosa.feature.delta(mfcc)

    onset_frames = librosa.onset.onset_detect(y=y, sr=sr)
    frames_to_time = librosa.frames_to_time(onset_frames[:20], sr=sr)




    # Transforming Features
    tempo_vector.at[id] =  tempo  # tempo
    total_beats.at[id] =  sum(beats)  # beats
    average_beats.at[id] =  np.average(beats)
    chroma_stft_mean.at[id] =  np.mean(chroma_stft)  # chroma stft
    chroma_stft_std.at[id] =  np.std(chroma_stft)
    chroma_stft_var.at[id] =  np.var(chroma_stft)
    chroma_cq_mean.at[id] =  np.mean(chroma_cq)  # chroma cq
    chroma_cq_std.at[id] =  np.std(chroma_cq)
    chroma_cq_var.at[id] =  np.var(chroma_cq)
    chroma_cens_mean.at[id] =  np.mean(chroma_cens)  # chroma cens
    chroma_cens_std.at[id] =  np.std(chroma_cens)
    chroma_cens_var.at[id] =  np.var(chroma_cens)
    mel_mean.at[id] =  np.mean(melspectrogram)  # melspectrogram
    mel_std.at[id] =  np.std(melspectrogram)
    mel_var.at[id] =  np.var(melspectrogram)
    mfcc_mean.at[id] =  np.mean(mfcc)  # mfcc
    mfcc_std.at[id] =  np.std(mfcc)
    mfcc_var.at[id] =  np.var(mfcc)
    mfcc_delta_mean.at[id] =  np.mean(mfcc_delta)  # mfcc delta
    mfcc_delta_std.at[id] =  np.std(mfcc_delta)
    mfcc_delta_var.at[id] =  np.var(mfcc_delta)
    rmse_mean.at[id] =  np.mean(rmse)  # rmse
    rmse_std.at[id] =  np.std(rmse)
    rmse_var.at[id] =  np.var(rmse)
    cent_mean.at[id] =  np.mean(cent)  # cent
    cent_std.at[id] =  np.std(cent)
    cent_var.at[id] =  np.var(cent)
    spec_bw_mean.at[id] =  np.mean(spec_bw)  # spectral bandwidth
    spec_bw_std.at[id] =  np.std(spec_bw)
    spec_bw_var.at[id] =  np.var(spec_bw)
    contrast_mean.at[id] =  np.mean(contrast)  # contrast
    contrast_std.at[id] =  np.std(contrast)
    contrast_var.at[id] =  np.var(contrast)
    rolloff_mean.at[id] =  np.mean(rolloff)  # rolloff
    rolloff_std.at[id] =  np.std(rolloff)
    rolloff_var.at[id] =  np.var(rolloff)
    poly_mean.at[id] =  np.mean(poly_features)  # poly features
    poly_std.at[id] =  np.std(poly_features)
    poly_var.at[id] =  np.var(poly_features)
    tonnetz_mean.at[id] =  np.mean(tonnetz)  # tonnetz
    tonnetz_std.at[id] =  np.std(tonnetz)
    tonnetz_var.at[id] =  np.var(tonnetz)
    zcr_mean.at[id] =  np.mean(zcr)  # zero crossing rate
    zcr_std.at[id] =  np.std(zcr)
    zcr_var.at[id] =  np.var(zcr)
    harm_mean.at[id] =  np.mean(harmonic)  # harmonic
    harm_std.at[id] =  np.std(harmonic)
    harm_var.at[id] =  np.var(harmonic)
    perc_mean.at[id] =  np.mean(percussive)  # percussive
    perc_std.at[id] =  np.std(percussive)
    perc_var.at[id] =  np.var(percussive)
    frame_mean.at[id] =  np.mean(frames_to_time)  # frames
    frame_std.at[id] =  np.std(frames_to_time)
    frame_var.at[id] =  np.var(frames_to_time)

    feature_set['tempo'] = tempo_vector  # tempo 
    feature_set['total_beats'] = total_beats  # beats
    feature_set['average_beats'] = average_beats
    feature_set['chroma_stft_mean'] = chroma_stft_mean  # chroma stft
    feature_set['chroma_stft_std'] = chroma_stft_std
    feature_set['chroma_stft_var'] = chroma_stft_var
    feature_set['chroma_cq_mean'] = chroma_cq_mean  # chroma cq
    feature_set['chroma_cq_std'] = chroma_cq_std
    feature_set['chroma_cq_var'] = chroma_cq_var
    feature_set['chroma_cens_mean'] = chroma_cens_mean  # chroma cens
    feature_set['chroma_cens_std'] = chroma_cens_std
    feature_set['chroma_cens_var'] = chroma_cens_var
    feature_set['melspectrogram_mean'] = mel_mean  # melspectrogram
    feature_set['melspectrogram_std'] = mel_std
    feature_set['melspectrogram_var'] = mel_var
    feature_set['mfcc_mean'] = mfcc_mean  # mfcc
    feature_set['mfcc_std'] = mfcc_std
    feature_set['mfcc_var'] = mfcc_var
    feature_set['mfcc_delta_mean'] = mfcc_delta_mean  # mfcc delta
    feature_set['mfcc_delta_std'] = mfcc_delta_std
    feature_set['mfcc_delta_var'] = mfcc_delta_var
    feature_set['rms_mean'] = rmse_mean  # rmse
    feature_set['rms_std'] = rmse_std
    feature_set['rms_var'] = rmse_var
    feature_set['cent_mean'] = cent_mean  # cent
    feature_set['cent_std'] = cent_std
    feature_set['cent_var'] = cent_var
    feature_set['spec_bw_mean'] = spec_bw_mean  # spectral bandwidth
    feature_set['spec_bw_std'] = spec_bw_std
    feature_set['spec_bw_var'] = spec_bw_var
    feature_set['contrast_mean'] = contrast_mean  # contrast
    feature_set['contrast_std'] = contrast_std
    feature_set['contrast_var'] = contrast_var
    feature_set['rolloff_mean'] = rolloff_mean  # rolloff
    feature_set['rolloff_std'] = rolloff_std
    feature_set['rolloff_var'] = rolloff_var
    feature_set['poly_mean'] = poly_mean  # poly features
    feature_set['poly_std'] = poly_std
    feature_set['poly_var'] = poly_var
    feature_set['tonnetz_mean'] = tonnetz_mean  # tonnetz
    feature_set['tonnetz_std'] = tonnetz_std
    feature_set['tonnetz_var'] = tonnetz_var
    feature_set['zcr_mean'] = zcr_mean  # zero crossing rate
    feature_set['zcr_std'] = zcr_std
    feature_set['zcr_var'] = zcr_var
    feature_set['harm_mean'] = harm_mean  # harmonic
    feature_set['harm_std'] = harm_std
    feature_set['harm_var'] = harm_var
    feature_set['perc_mean'] = perc_mean  # percussive
    feature_set['perc_std'] = perc_std
    feature_set['perc_var'] = perc_var
    feature_set['frame_mean'] = frame_mean  # frames
    feature_set['frame_std'] = frame_std
    feature_set['frame_var'] = frame_var
    
    return feature_set

f = fn_song_features('Nick Cave & The Bad Seeds - Straight To You-CYbOHXMtelU.wav')
g = fn_song_features('Alec Benjamin - Jesus in LA [Official Music Video]-eNbUNSNdYu4.wav')
h = fn_song_features('Tareefan _ Veere Di Wedding _ QARAN  Ft. Badshah _ Kareena Kapoor Khan, Sonam Kapoor, Swara & Shikha-3SWc5G8Gx7E.wav')

# %% [markdown]
# #  Libraries Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Preparing Datasets
#
# ## Reading CSV

# %%
df1 = pd.read_csv('Emotion_feat.csv',encoding='cp1252')
df2 = pd.read_csv('Emotion_feat1.csv',encoding='cp1252')

# %%
#dropping the na values

df1.dropna(inplace=True)
df2.dropna(inplace=True)

# %% [markdown]
# ## Complete Dataset

# %%
#Making a single dataframe with append 

df_data = df1.append(df2)

# %%
#columns of the data

print(list(df_data.columns))
# Out:
# ['Unnamed: 0', 'energy', 'valance', 'song_name', 'tempo', 'total_beats', 'average_beats', 'chroma_stft_mean', 'chroma_stft_std', 'chroma_stft_var', 'chroma_cq_mean', 'chroma_cq_std', 'chroma_cq_var', 'chroma_cens_mean', 'chroma_cens_std', 'chroma_cens_var', 'melspectrogram_mean', 'melspectrogram_std', 'melspectrogram_var', 'mfcc_mean', 'mfcc_std', 'mfcc_var', 'mfcc_delta_mean', 'mfcc_delta_std', 'mfcc_delta_var', 'rms_mean', 'rms_std', 'rms_var', 'cent_mean', 'cent_std', 'cent_var', 'spec_bw_mean', 'spec_bw_std', 'spec_bw_var', 'contrast_mean', 'contrast_std', 'contrast_var', 'rolloff_mean', 'rolloff_std', 'rolloff_var', 'poly_mean', 'poly_std', 'poly_var', 'tonnetz_mean', 'tonnetz_std', 'tonnetz_var', 'zcr_mean', 'zcr_std', 'zcr_var', 'harm_mean', 'harm_std', 'harm_var', 'perc_mean', 'perc_std', 'perc_var', 'frame_mean', 'frame_std', 'frame_var']

# %%
# A look of the dataset
df_data.head()
# Out:
#    Unnamed: 0  energy  valance  \
# 0         1.0   0.710    0.511
# 1         2.0   0.668    0.608
# 2         3.0   0.693    0.550
# 3         4.0   0.743    0.571
# 4         5.0   0.844    0.675
#
#                                            song_name       tempo  total_beats  \
# 0  AJ Mitchell - Say It Again (Lyric Video)-8irY4...  117.453835     151621.0
# 1  Alan Walker & Ava Max - Alone, Pt. II-HhjHYkPQ...  117.453835      89451.0
# 2  Alesso - Sad Song (feat. TINI) _ Official Musi...  112.347147     139388.0
# 3  Anne-Marie & James Arthur - Rewrite The Stars ...  129.199219     157979.0
# 4  Anne-Marie - Perfect To Me [Official Music Vid...   89.102909     108947.0
#
#    average_beats  chroma_stft_mean  chroma_stft_std  chroma_stft_var  ...  \
# 0    1307.077586          0.342291         0.303527         0.092129  ...
# 1    1005.067416          0.364378         0.306120         0.093709  ...
# 2    1407.959596          0.299974         0.305903         0.093577  ...
# ...

# %%
# dropping useless column
df_data.drop('Unnamed: 0',inplace=True,axis=1)

# %%
## Storing the energy and valence as variables

ene = pd.Series(df_data.energy).reset_index()
val = pd.Series(df_data.valance).reset_index()

# %%
## Name of all predictor variables
predictors = list(df_data.columns.drop(['valance','energy','song_name']))

# %% [markdown]
# ## Dataframe with all predictor variables

# %%
x = df_data[predictors]

# %%
def fn_get_DataType_of_Columns(df):
    d = df.columns.to_series().groupby(df.dtypes).groups
    for x in d:
        print(f"{' ,'.join(d[x])} are of datatype :  '{str(x)} '. ")
        
fn_get_DataType_of_Columns(x)
# Out:
# tempo ,total_beats ,average_beats ,chroma_stft_mean ,chroma_stft_std ,chroma_stft_var ,chroma_cq_mean ,chroma_cq_std ,chroma_cq_var ,chroma_cens_mean ,chroma_cens_std ,chroma_cens_var ,melspectrogram_mean ,melspectrogram_std ,melspectrogram_var ,mfcc_mean ,mfcc_std ,mfcc_var ,mfcc_delta_mean ,mfcc_delta_std ,mfcc_delta_var ,rms_mean ,rms_std ,rms_var ,cent_mean ,cent_std ,cent_var ,spec_bw_mean ,spec_bw_std ,spec_bw_var ,contrast_mean ,contrast_std ,contrast_var ,rolloff_mean ,rolloff_std ,rolloff_var ,poly_mean ,poly_std ,poly_var ,tonnetz_mean ,tonnetz_std ,tonnetz_var ,zcr_mean ,zcr_std ,zcr_var ,harm_mean ,harm_std ,harm_var ,perc_mean ,perc_std ,perc_var ,frame_mean ,frame_std ,frame_var are of datatype :  'float64 '.

# %%
def fn_uniqueInEveryColumns(df):
    b = []
    for x in df: 
        if x not in b:
            c = []
            for cols in df.columns.drop(x):
                if(df[x].nunique() == df[cols].nunique()):
                            c.append(cols)
                            b.append(cols)
            if len(c) != 0: 
                print("'"," ', ' ".join(c),"'", 'and',"'",x,"'", 'has same number of unique values =',df[x].nunique()) 
            else: 
                print("'",x,"'",'feature has distinct values =',df[x].nunique()) 
                
fn_uniqueInEveryColumns(x)
# Out:
# ' tempo ' feature has distinct values = 29
# ' average_beats ', ' chroma_stft_mean ', ' chroma_stft_std ', ' chroma_stft_var ', ' chroma_cq_mean ', ' chroma_cq_std ', ' chroma_cq_var ', ' chroma_cens_mean ', ' chroma_cens_std ', ' chroma_cens_var ', ' melspectrogram_mean ', ' melspectrogram_std ', ' melspectrogram_var ', ' mfcc_mean ', ' mfcc_std ', ' mfcc_var ', ' mfcc_delta_mean ', ' mfcc_delta_std ', ' mfcc_delta_var ', ' rms_mean ', ' rms_std ', ' rms_var ', ' cent_mean ', ' cent_std ', ' cent_var ', ' spec_bw_mean ', ' spec_bw_std ', ' spec_bw_var ', ' contrast_mean ', ' contrast_std ', ' contrast_var ', ' rolloff_mean ', ' rolloff_std ', ' rolloff_var ', ' poly_mean ', ' poly_std ', ' poly_var ', ' tonnetz_mean ', ' tonnetz_std ', ' tonnetz_var ', ' zcr_mean ', ' zcr_std ', ' zcr_var ', ' harm_std ', ' harm_var ', ' perc_std ', ' perc_var ', ' frame_std ', ' frame_var ' and ' total_beats ' has same number of unique values = 203
# ' harm_mean ' feature has distinct values = 196
# ...

# %% [markdown]
# # Statistical Approach towards data
# ## Outlier check in energy an valance

# %%
plt.figure(figsize=(5,5))
plt.title("Energy Box Plot")
plt.boxplot(ene.energy)
plt.show()

plt.figure(figsize=(5, 5))
plt.title("Energy Distribution Plot")
sns.distplot(ene.energy)
plt.show()


plt.figure(figsize=(5,5))
plt.title("Valence Box Plot")
plt.boxplot(val.valance)
plt.show()

plt.figure(figsize=(5, 5))
plt.title("Valence Distribution Plot")
sns.distplot(val.valance)
plt.show()

# %%
# statistical property of the columns

df_data.describe().T
# Out:
#                      count          mean            std            min  \
# energy               205.0  6.053356e-01       0.188930       0.084800
# valance              205.0  4.863776e-01       0.204289       0.038500
# tempo                205.0  1.165165e+02      27.653212      53.833008
# total_beats          205.0  1.420599e+05   36272.181386   62516.000000
# average_beats        205.0  1.306744e+03     106.583248     839.936842
# chroma_stft_mean     205.0  3.309592e-01       0.047951       0.209007
# chroma_stft_std      205.0  3.067082e-01       0.008230       0.280841
# chroma_stft_var      205.0  9.413731e-02       0.005066       0.078872
# chroma_cq_mean       205.0  4.417958e-01       0.049343       0.262745
# chroma_cq_std        205.0  2.878921e-01       0.011013       0.260251
# chroma_cq_var        205.0  8.300257e-02       0.006339       0.067731
# chroma_cens_mean     205.0  2.432259e-01       0.013984       0.177854
# ...

# %% [markdown]
# ## Scaling the predictor data

# %%
#we are using MinMax Scaler

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
XScaled = pd.DataFrame(scaler.fit_transform(x))
XScaled.columns = x.columns

# %%
XScaled.describe().T
# Out:
#                      count          mean       std       min       25%  \
# tempo                205.0 -1.418919e-16  1.002448 -2.272320 -0.621064
# total_beats          205.0 -2.599547e-16  1.002448 -2.198340 -0.756195
# average_beats        205.0  2.544712e-15  1.002448 -4.390463 -0.425773
# chroma_stft_mean     205.0 -9.352952e-16  1.002448 -2.549520 -0.647780
# chroma_stft_std      205.0 -7.395913e-15  1.002448 -3.150845 -0.618025
# chroma_stft_var      205.0  2.046331e-15  1.002448 -3.020781 -0.624109
# chroma_cq_mean       205.0 -9.954097e-16  1.002448 -3.637607 -0.640196
# chroma_cq_std        205.0  2.627708e-15  1.002448 -2.516012 -0.658933
# chroma_cq_var        205.0  1.620384e-15  1.002448 -2.414907 -0.669895
# chroma_cens_mean     205.0 -7.701157e-16  1.002448 -4.686332 -0.536046
# chroma_cens_std      205.0 -6.758821e-16  1.002448 -2.686361 -0.667735
# chroma_cens_var      205.0 -6.065609e-17  1.002448 -2.219548 -0.689093
# ...

# %%
#creating energy and valance dataframe

#df_ene = pd.concat([XScaled,ene.energy],axis=1)
#df_val = pd.concat([XScaled,val.valance],axis=1)

df_ene  = x
df_val = x

df_ene['energy'] = ene.energy
df_val['valance'] = val.valance
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_ene = df_ene.drop('valance',axis=1)

# %%
df_ene.head()
# Out:
#         tempo  total_beats  average_beats  chroma_stft_mean  chroma_stft_std  \
# 0  117.453835     151621.0    1307.077586          0.342291         0.303527
# 1  117.453835      89451.0    1005.067416          0.364378         0.306120
# 2  112.347147     139388.0    1407.959596          0.299974         0.305903
# 3  129.199219     157979.0    1305.611570          0.332029         0.303948
# 4   89.102909     108947.0    1238.034091          0.345379         0.314045
#
#    chroma_stft_var  chroma_cq_mean  chroma_cq_std  chroma_cq_var  \
# 0         0.092129        0.499715       0.290345       0.084300
# 1         0.093709        0.506222       0.284352       0.080856
# 2         0.093577        0.417524       0.302515       0.091516
# 3         0.092384        0.494529       0.276839       0.076640
# 4         0.098624        0.455335       0.288880       0.083452
#
#    chroma_cens_mean  ...     harm_mean  harm_std  harm_var  perc_mean  \
# ...

# %%
#heatmap correlation plot for energy dataframe

plt.figure(figsize=(20,20))
sns.heatmap(df_data.corr(),square=True,vmax=1,vmin=-1,cmap='Set1',linewidths=0.5)
plt.show()

# %% [markdown]
# # Feature Selection for Energy
#
# Here we will be looking for important features with the coefficients of different ML models.
#
# ## Correlation

# %%
plt.figure(figsize=(10,10))
correlation=abs(df_ene.corr()['energy'])
del correlation['energy']
correlation.sort_values(ascending=True).plot(kind='barh')
plt.yticks(ha='right')
plt.show()

# %%
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score
cross_val_score(Ridge(), x, ene.energy, scoring="neg_mean_squared_error", cv = 5)
# Out:
# array([-0.02354062, -0.02675053, -0.0181011 , -0.01800148, -0.02564641])

# %%
alphas = [0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 50, 75]
def rmse_cv(model):
    rmse= np.sqrt(-cross_val_score(model, x, ene.energy, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)
cv_ridge = [rmse_cv(Ridge(alpha = alpha)).mean() 
            for alpha in alphas]
cv_ridge = pd.Series(cv_ridge, index = alphas)
cv_ridge.plot(title = "Validation")
plt.xlabel("alpha")
plt.ylabel("rmse")
# Out:
# Text(0, 0.5, 'rmse')

# %% [markdown]
# ## Model Lasso regression

# %%
###Model Lasso regression
model_lasso = LassoCV(alphas = [1, 0.1, 0.001, 0.0005],random_state=2020,max_iter=10000).fit(x, ene.energy)
rmse_cv(model_lasso).mean()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0015910854252143558, tolerance: 0.000555214726902439
#   tol, rng, random, positive)
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07070561600761227, tolerance: 0.000585299735804878
#   tol, rng, random, positive)
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0031235012755677083, tolerance: 0.00047190481893129776
#   tol, rng, random, positive)
# ...

# %%
###Model Lasso regression
coef = pd.Series(model_lasso.coef_, index = x.columns)
coef.head()
# Out:
# tempo               0.000000e+00
# total_beats        -3.472986e-07
# average_beats       2.029277e-04
# chroma_stft_mean    0.000000e+00
# chroma_stft_std    -0.000000e+00
# dtype: float64

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 12 variables and eliminated the other 44 variables

# %%
plt.rcParams['figure.figsize'] = (8.0, 10.0)
lassocoeff = pd.Series((model_lasso.coef_), index=x.columns)
lassocoeff.sort_values(ascending=True).plot(kind='barh')
plt.show()



imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
plt.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
plt.show()

normLasso = lassocoeff/np.linalg.norm(lassocoeff)
normLasso = pd.Series(abs(normLasso), index=x.columns)
normLasso.sort_values(ascending=True).plot(kind='bar')
plt.show()


plt.rcParams['figure.figsize'] = (6.0, 6.0)
preds = pd.DataFrame({"preds":model_lasso.predict(x), "true":ene.energy})
preds["residuals"] = preds["true"] - preds["preds"]
preds.plot(x = "preds", y = "residuals",kind = "scatter")
plt.show()


#Here notice the 'imp_coef' will give us the important features that will be of our major interest.

# %%
imp_coef.keys()
# Out:
# Index(['melspectrogram_std', 'mfcc_var', 'total_beats', 'rolloff_var',
#        'cent_var', 'perc_std', 'contrast_mean', 'contrast_std', 'rolloff_std',
#        'frame_std', 'cent_mean', 'chroma_cq_mean', 'chroma_stft_var',
#        'spec_bw_var', 'melspectrogram_var', 'rolloff_mean', 'spec_bw_mean',
#        'average_beats', 'frame_var', 'contrast_var'],
#       dtype='object')

# %% [markdown]
# ## Model Ridge regression

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(x,ene.energy)
ridgecoeff = pd.Series((ridge.coef_), index=x.columns)
ridgecoeff.sort_values(ascending=True).plot(kind='barh')
plt.show()
normRidge = ridgecoeff/np.linalg.norm(ridgecoeff)
normRidge = pd.Series(abs(normRidge), index=x.columns)
normRidge.sort_values(ascending=True).plot(kind='bar')
plt.yticks(ha='right')
plt.show()

# %%
plt.figure(figsize=(10,10))

from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x,ene.energy)
feat_importances1 = pd.Series(dt.feature_importances_, index=x.columns)
feat_importances1.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %% [markdown]
# ## RandomForestRegressor

# %%
plt.figure(figsize=(10,10))

from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x,ene.energy)
feat_importances2 = pd.Series(rf.feature_importances_, index=x.columns)
feat_importances2.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %%
feat_importances2.sort_values(ascending=True)[-5:]
# Out:
# mfcc_mean       0.045977
# contrast_std    0.066450
# contrast_var    0.118835
# rolloff_mean    0.144804
# energy          0.168726
# dtype: float64

# %%
feat_importances2.sort_values(ascending=True)[-5:]
# Out:
# mfcc_mean       0.045977
# contrast_std    0.066450
# contrast_var    0.118835
# rolloff_mean    0.144804
# energy          0.168726
# dtype: float64

# %%
plt.figure(figsize=(10,10))


from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(XScaled,val.valance)
feat_importances2 = pd.Series(rf.feature_importances_, index=XScaled.columns)
feat_importances2.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %% [markdown]
# ## ExtraTreesRegressor

# %%
plt.figure(figsize=(10,10))

from sklearn.ensemble import ExtraTreesRegressor
et=ExtraTreesRegressor()
et.fit(XScaled,ene.energy)
feat_importances3 = pd.Series(et.feature_importances_, index=XScaled.columns)
feat_importances3.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %% [markdown]
# ## GradientBoostingRegressor

# %%
plt.figure(figsize=(10,10))

from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(XScaled,ene.energy)
feat_importances4 = pd.Series(gbr.feature_importances_, index=XScaled.columns)


plt.rcParams['figure.figsize'] = (8,10)

feat_importances4.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %%
combinedDf = {
        'DecisionTree': feat_importances1,
        'RandomForest': feat_importances2,
        'ExtraTrees': feat_importances3,
        'GradientBoostedTrees': feat_importances4,
        'Lasso':normLasso,
        'Ridge':normRidge,
        'CorrelationMatrix':correlation}

# %%
pd.DataFrame(combinedDf)
# Out:
#                      DecisionTree  RandomForest  ExtraTrees  \
# average_beats        1.105120e-02      0.014245    0.012862
# cent_mean            8.097513e-04      0.140353    0.029898
# cent_std             7.911429e-05      0.004216    0.008508
# cent_var             5.933793e-03      0.003981    0.007331
# chroma_cens_mean     1.707311e-03      0.032003    0.006038
# chroma_cens_std      2.207738e-03      0.008966    0.006674
# chroma_cens_var      1.345847e-05      0.012209    0.006689
# chroma_cq_mean       6.710587e-03      0.016187    0.008052
# chroma_cq_std        3.658163e-05      0.014537    0.021553
# chroma_cq_var        3.286064e-02      0.018758    0.023062
# chroma_stft_mean     2.927217e-04      0.027101    0.027893
# chroma_stft_std      0.000000e+00      0.025997    0.018100
# chroma_stft_var      1.250533e-03      0.017918    0.017907
# contrast_mean        1.876791e-02      0.027638    0.016301
# contrast_std         1.288073e-03      0.035809    0.069754
# ...

# %%
weight1= np.random.randint(1,10)/10
weight2= np.random.randint(1,10)/10
weight3= np.random.randint(1,10)/10
weight4= np.random.randint(1,10)/10
weight5= np.random.randint(1,10)/10
weight6= np.random.randint(1,10)/10
weight7= np.random.randint(1,10)/10
weightSum=weight1+weight2+weight3+weight4+weight5+weight6+weight7

# %%
feat=(weight1*feat_importances1+weight2*feat_importances2
      +weight3*feat_importances3+weight4*feat_importances4+
      weight5*normLasso+weight6*normRidge+weight7*correlation)/(weightSum)

# %% [markdown]
# ## Important Features

# %%
plt.figure(figsize=(15,10))
feat.sort_values(ascending=True).plot(kind='bar')
plt.show()

# %%
#important features
list(feat.sort_values(ascending=False)[0:7].keys())
# Out:
# ['contrast_var',
#  'melspectrogram_std',
#  'contrast_std',
#  'frame_var',
#  'rolloff_mean',
#  'mfcc_delta_std',
#  'poly_std']

# %% [markdown]
#  # Machine Learning Models for Energy Prediction
#  ## Linear Regressions

# %%
features_new = list(feat.sort_values(ascending=False)[0:7].keys())

# %%
df = x[features_new]

df['energy']=ene.energy
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.model_selection import train_test_split

train,test = train_test_split(df,test_size=0.25,random_state = 2020)

predictors = list(df.columns[df.columns != 'energy'])

# %%
equation = 'energy' + '~' + '+'.join(predictors)

# %%
equation
# Out:
# 'energy~contrast_var+melspectrogram_std+contrast_std+frame_var+rolloff_mean+mfcc_delta_std+poly_std'

# %%
import statsmodels.formula.api as smf
model_OLS = smf.ols(formula = equation, data=train)
model_OLS = model_OLS.fit()
model_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 energy   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     1.622
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):              0.133
# Time:                        13:25:17   Log-Likelihood:                 72.235
# No. Observations:                 153   AIC:                            -128.5
# Df Residuals:                     145   BIC:                            -104.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
print(model_OLS.conf_int().index)
# Out:
# Index(['Intercept', 'contrast_var', 'melspectrogram_std', 'contrast_std',
#        'frame_var', 'rolloff_mean', 'mfcc_delta_std', 'poly_std'],
#       dtype='object')

# %%
pred_y = model_OLS.predict(test)

plt.figure(figsize=(5,  5))
sns.regplot(test.energy, pred_y)

plt.xlabel('“True Values”')
plt.ylabel('“Predictions”')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(test.energy,pred_y)
# Out:
# 0.02202296986065414

# %%
equation
# Out:
# 'energy~contrast_var+melspectrogram_std+contrast_std+frame_var+rolloff_mean+mfcc_delta_std+poly_std'

# %%
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

#gather features


# get y and X dataframes based on this regression:
y, X = dmatrices(equation, df, return_type='dataframe')


vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"] = X.columns
vif.round(1)

#rolloff_mean
#harm_std
#spec_bw_mean
#mfcc_var
# Out:
#    VIF Factor            Features
# 0     12543.2           Intercept
# 1       352.9        contrast_var
# 2         3.0  melspectrogram_std
# 3       342.8        contrast_std
# 4         1.1           frame_var
# 5         5.1        rolloff_mean
# 6         1.2      mfcc_delta_std
# 7         3.6            poly_std

# %% [markdown]
# ## Random Forest

# %%
rf_energy=RandomForestRegressor(random_state=2020,bootstrap=False,warm_start=True)
rf_energy.fit(x[features_new],ene.energy)
# Out:
# RandomForestRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=2020, verbose=0, warm_start=True)

# %%
n_nodes = []
max_depths = []

# Stats about the trees in random forest
for ind_tree in rf_energy.estimators_:
    n_nodes.append(ind_tree.tree_.node_count)
    max_depths.append(ind_tree.tree_.max_depth)
    
print(f'Average number of nodes {int(np.mean(n_nodes))}')
print(f'Average maximum depth {int(np.mean(max_depths))}')
# Out:
# Average number of nodes 401
# Average maximum depth 15

# %%
rf_energy.predict(f[features_new])
# Out:
# array([0.778])

# %%
rf_energy.predict(g[features_new])
# Out:
# array([0.627])

# %%
rf_energy.predict(h[features_new])
# Out:
# array([0.53284])

# %% [markdown]
# # Saving the model for energy prediction

# %%
# the modelR has the best score of 0.8283428235369121 so 
# Pickled modelR as a file using joblib

import joblib
import pickle
joblib.dump(rf_energy, 'energy.pkl')
# Out:
# ['energy.pkl']

# %%
energy = joblib.load('energy.pkl')
energy.predict(h[features_new])
# Out:
# array([0.53284])

# %% [markdown]
# # Feature Selection for Valance

# %%
df_val.head()
# Out:
#         tempo  total_beats  average_beats  chroma_stft_mean  chroma_stft_std  \
# 0  117.453835     151621.0    1307.077586          0.342291         0.303527
# 1  117.453835      89451.0    1005.067416          0.364378         0.306120
# 2  112.347147     139388.0    1407.959596          0.299974         0.305903
# 3  129.199219     157979.0    1305.611570          0.332029         0.303948
# 4   89.102909     108947.0    1238.034091          0.345379         0.314045
#
#    chroma_stft_var  chroma_cq_mean  chroma_cq_std  chroma_cq_var  \
# 0         0.092129        0.499715       0.290345       0.084300
# 1         0.093709        0.506222       0.284352       0.080856
# 2         0.093577        0.417524       0.302515       0.091516
# 3         0.092384        0.494529       0.276839       0.076640
# 4         0.098624        0.455335       0.288880       0.083452
#
#    chroma_cens_mean  ...  harm_std  harm_var  perc_mean  perc_std  perc_var  \
# ...

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize=(10,10))
correlation=abs(df_val.corr()['valance'])
del correlation['valance']
correlation.sort_values(ascending=True).plot(kind='barh')
plt.yticks(ha='right')
plt.show()

# %%
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score
cross_val_score(Ridge(), x, val.valance, scoring="neg_mean_squared_error", cv = 5)
# Out:
# array([-0.02091403, -0.0189232 , -0.02312972, -0.03729278, -0.03037064])

# %%
alphas = [0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 50, 75]
def rmse_cv(model):
    rmse= np.sqrt(-cross_val_score(model, x, val.valance, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)
cv_ridge = [rmse_cv(Ridge(alpha = alpha)).mean() 
            for alpha in alphas]
cv_ridge = pd.Series(cv_ridge, index = alphas)
cv_ridge.plot(title = "Validation")
plt.xlabel("alpha")
plt.ylabel("rmse")
# Out:
# Text(0, 0.5, 'rmse')

# %% [markdown]
# ## Model Lasso regression

# %%
###Model Lasso regression
model_lasso = LassoCV(alphas = [1, 0.1, 0.001, 0.0005],random_state=2020,max_iter=10000).fit(x, val.valance)
rmse_cv(model_lasso).mean()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11920955660663468, tolerance: 0.0004882920983053434
#   tol, rng, random, positive)
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.056399579578471304, tolerance: 0.0005338031572366413
#   tol, rng, random, positive)
# 0.15972787494535035

# %%
###Model Lasso regression
coef = pd.Series(model_lasso.coef_, index = x.columns)
coef.head()
# Out:
# tempo              -6.551176e-04
# total_beats         1.895244e-07
# average_beats      -2.995620e-05
# chroma_stft_mean   -0.000000e+00
# chroma_stft_std     0.000000e+00
# dtype: float64

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 27 variables and eliminated the other 29 variables

# %%
plt.rcParams['figure.figsize'] = (8.0, 10.0)
lassocoeff = pd.Series((model_lasso.coef_), index=x.columns)
lassocoeff.sort_values(ascending=True).plot(kind='barh')
plt.show()



imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
plt.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
plt.show()

normLasso = lassocoeff/np.linalg.norm(lassocoeff)
normLasso = pd.Series(abs(normLasso), index=x.columns)
normLasso.sort_values(ascending=True).plot(kind='bar')
plt.show()


plt.rcParams['figure.figsize'] = (6.0, 6.0)
preds = pd.DataFrame({"preds":model_lasso.predict(x), "true":ene.energy})
preds["residuals"] = preds["true"] - preds["preds"]
preds.plot(x = "preds", y = "residuals",kind = "scatter")
plt.show()


#Here notice the 'imp_coef' will give us the important features that will be of our major interest.

# %%
imp_coef.keys()
# Out:
# Index(['contrast_mean', 'mfcc_std', 'mfcc_mean', 'poly_std',
#        'melspectrogram_mean', 'melspectrogram_std', 'cent_std', 'tempo',
#        'contrast_var', 'frame_var', 'cent_var', 'melspectrogram_var',
#        'mfcc_var', 'rolloff_std', 'spec_bw_std', 'spec_bw_mean', 'frame_std',
#        'poly_var', 'mfcc_delta_var', 'valance'],
#       dtype='object')

# %% [markdown]
# ## Model Ridge regression

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(XScaled,ene.energy)
ridgecoeff = pd.Series((ridge.coef_), index=XScaled.columns)
ridgecoeff.sort_values(ascending=True).plot(kind='barh')
plt.show()
normRidge = ridgecoeff/np.linalg.norm(ridgecoeff)
normRidge = pd.Series(abs(normRidge), index=XScaled.columns)
normRidge.sort_values(ascending=True).plot(kind='bar')
plt.yticks(ha='right')
plt.show()

# %%
plt.figure(figsize=(10,10))

from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x, val.valance)
feat_importances1 = pd.Series(dt.feature_importances_, index=x.columns)
feat_importances1.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %% [markdown]
# ## RandomForestRegressor

# %%
plt.figure(figsize=(10,10))

from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x, val.valance)
feat_importances2 = pd.Series(rf.feature_importances_, index=x.columns)
feat_importances2.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %%
feat_importances2.sort_values(ascending=True)[-5:]
# Out:
# rolloff_mean      0.037846
# mfcc_delta_std    0.040987
# spec_bw_mean      0.060263
# cent_mean         0.126775
# valance           0.238290
# dtype: float64

# %%
feat_importances2.sort_values(ascending=True)[-5:]
# Out:
# rolloff_mean      0.037846
# mfcc_delta_std    0.040987
# spec_bw_mean      0.060263
# cent_mean         0.126775
# valance           0.238290
# dtype: float64

# %%
plt.figure(figsize=(10,10))


from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x, val.valance)
feat_importances2 = pd.Series(rf.feature_importances_, index=x.columns)
feat_importances2.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %% [markdown]
# ## ExtraTreesRegressor

# %%
plt.figure(figsize=(10,10))

from sklearn.ensemble import ExtraTreesRegressor
et=ExtraTreesRegressor()
et.fit(x, val.valance)
feat_importances3 = pd.Series(et.feature_importances_, index=x.columns)
feat_importances3.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %% [markdown]
# ## GradientBoostingRegressor

# %%
plt.figure(figsize=(10,10))

from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(x, val.valance)
feat_importances4 = pd.Series(gbr.feature_importances_, index=x.columns)


plt.rcParams['figure.figsize'] = (8,10)

feat_importances4.sort_values(ascending=True).plot(kind='bar')
plt.xticks(ha='right')
plt.show()

# %%
combinedDf = {
        'DecisionTree': feat_importances1,
        'RandomForest': feat_importances2,
        'ExtraTrees': feat_importances3,
        'GradientBoostedTrees': feat_importances4,
        'Lasso':normLasso,
        'Ridge':normRidge,
        'CorrelationMatrix':correlation}

# %%
pd.DataFrame(combinedDf)
# Out:
#                      DecisionTree  RandomForest  ExtraTrees  \
# average_beats            0.014420      0.009569    0.008358
# cent_mean                0.233023      0.107667    0.040554
# cent_std                 0.000002      0.003175    0.004798
# cent_var                 0.002505      0.002447    0.004934
# chroma_cens_mean         0.006185      0.015775    0.010979
# chroma_cens_std          0.016923      0.009749    0.010867
# chroma_cens_var          0.000041      0.006479    0.014802
# chroma_cq_mean           0.000566      0.009015    0.007534
# chroma_cq_std            0.001406      0.004498    0.010203
# chroma_cq_var            0.023781      0.008292    0.010878
# chroma_stft_mean         0.001118      0.024362    0.009849
# chroma_stft_std          0.025696      0.012994    0.015673
# chroma_stft_var          0.000462      0.017484    0.014356
# contrast_mean            0.049268      0.016823    0.012943
# contrast_std             0.000213      0.032488    0.052032
# ...

# %%
weight1= np.random.randint(1,10)/10
weight2= np.random.randint(1,10)/10
weight3= np.random.randint(1,10)/10
weight4= np.random.randint(1,10)/10
weight5= np.random.randint(1,10)/10
weight6= np.random.randint(1,10)/10
weight7= np.random.randint(1,10)/10
weightSum=weight1+weight2+weight3+weight4+weight5+weight6+weight7

# %%
feat=(weight1*feat_importances1+weight2*feat_importances2
      +weight3*feat_importances3+weight4*feat_importances4+
      weight5*normLasso+weight6*normRidge+weight7*correlation)/(weightSum)

# %% [markdown]
# ## Important Features

# %%
plt.figure(figsize=(15,10))
feat.sort_values(ascending=True).plot(kind='bar')
plt.show()

# %%
#important features
list(feat.sort_values(ascending=False)[0:8].keys())
# Out:
# ['cent_mean',
#  'mfcc_delta_std',
#  'contrast_mean',
#  'spec_bw_mean',
#  'harm_std',
#  'mfcc_delta_var',
#  'mfcc_var',
#  'contrast_var']

# %%
features = list(feat.sort_values(ascending=False)[0:8].keys())

df = x[features]
df['valance']  = val.valance

from sklearn.model_selection import train_test_split

train,test = train_test_split(df,test_size=0.25,random_state = 2020)

predictors = list(df.columns[df.columns != 'valance'])

equation = 'valance' + '~' + '+'.join(features)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# # Machine Learning model for Valance
# ## Linear Regression

# %%
equation
# Out:
# 'valance~cent_mean+mfcc_delta_std+contrast_mean+spec_bw_mean+harm_std+mfcc_delta_var+mfcc_var+contrast_var'

# %%
import statsmodels.formula.api as smf
model_OLS = smf.ols(formula = equation, data=train)
model_OLS = model_OLS.fit()
model_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                valance   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     1.756
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):             0.0905
# Time:                        13:25:40   Log-Likelihood:                 48.058
# No. Observations:                 153   AIC:                            -78.12
# Df Residuals:                     144   BIC:                            -50.84
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
equation
# Out:
# 'valance~cent_mean+mfcc_delta_std+contrast_mean+spec_bw_mean+harm_std+mfcc_delta_var+mfcc_var+contrast_var'

# %%
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

#gather features


# get y and X dataframes based on this regression:
y, X = dmatrices(equation, df, return_type='dataframe')


vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"] = X.columns

vif.round(1)

# mfcc_std cent_std poly_std melspectrogram_std melspectrogram_mean frame_std spec_bw_mean rolloff_std mfcc_var
# Out:
#    VIF Factor        Features
# 0      1819.8       Intercept
# 1         7.1       cent_mean
# 2        61.3  mfcc_delta_std
# 3         1.1   contrast_mean
# 4        11.9    spec_bw_mean
# 5         2.9        harm_std
# 6        61.2  mfcc_delta_var
# 7         6.1        mfcc_var
# 8         7.5    contrast_var

# %%
X.columns
# Out:
# Index(['Intercept', 'cent_mean', 'mfcc_delta_std', 'contrast_mean',
#        'spec_bw_mean', 'harm_std', 'mfcc_delta_var', 'mfcc_var',
#        'contrast_var'],
#       dtype='object')

# %% [markdown]
# ##  Random Forest

# %%
rf=RandomForestRegressor(random_state=2020,bootstrap=True,warm_start=True)
rf.fit(x[features],val.valance)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=2020, verbose=0, warm_start=True)

# %%
n_nodes = []
max_depths = []

# Stats about the trees in random forest
for ind_tree in rf.estimators_:
    n_nodes.append(ind_tree.tree_.node_count)
    max_depths.append(ind_tree.tree_.max_depth)
    
print(f'Average number of nodes {int(np.mean(n_nodes))}')
print(f'Average maximum depth {int(np.mean(max_depths))}')
# Out:
# Average number of nodes 255
# Average maximum depth 14

# %%
rf.predict(f[features])
# Out:
# array([0.437146])

# %%
rf.predict(g[features])
# Out:
# array([0.63398])

# %%
rf.predict(h[features])
# Out:
# array([0.620378])

# %% [markdown]
# # Saving the model for Valance prediction

# %%
import pickle

# %%
# the model has the score of 0.8231378916534265 so 
# Pickled model as a file using joblib

joblib.dump(rf, 'valance.pkl')
# Out:
# ['valance.pkl']

# %%
m = joblib.load('valance.pkl')

# %%
m.predict(h[features])
# Out:
# array([0.620378])
