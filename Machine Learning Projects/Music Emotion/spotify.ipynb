# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
client_id = "ca830724aae142a5aaa244d4f0c770aa"
client_secret = "133eff40730a4738a1326f318c6636d8"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
artist_name = []
track_name = []
popularity = []
track_id = []

for i in range(0,10000,50):
    track_results = sp.search(q='track:Straight To You && artist:Nick Cave', type='track')
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])

# %%
import pandas as pd
import numpy as np

# %%
df_tracks = pd.DataFrame({'artist_name':artist_name,'track_name':track_name,'track_id':track_id,'popularity':popularity})
print(df_tracks.shape)
df_tracks.head()
# Out:
# (400, 4)
#                  artist_name                                 track_name  \
# 0  Nick Cave & The Bad Seeds  Straight to You - 2010 Remastered Version
# 1  Nick Cave & The Bad Seeds  Straight to You - 2010 Remastered Version
# 2  Nick Cave & The Bad Seeds  Straight to You - 2010 Remastered Version
# 3  Nick Cave & The Bad Seeds  Straight to You - 2010 Remastered Version
# 4  Nick Cave & The Bad Seeds  Straight to You - 2010 Remastered Version
#
#                  track_id  popularity
# 0  3ZMQOrCj7exXxV7NmCiorW          40
# 1  7sTfLbRGZ74dbVVYfNc8Kk          26
# 2  3ZMQOrCj7exXxV7NmCiorW          40
# 3  7sTfLbRGZ74dbVVYfNc8Kk          26
# 4  3ZMQOrCj7exXxV7NmCiorW          40

# %%
rows = []
batchsize = 100
None_counter = 0
feature_results = []
for i in range(0,len(df_tracks['track_id']),batchsize):
    batch = df_tracks['track_id'][i:i+batchsize]
    feature_results = sp.audio_features(batch)
feature_results
# Out:
# [{'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '3ZMQOrCj7exXxV7NmCiorW',
#   'uri': 'spotify:track:3ZMQOrCj7exXxV7NmCiorW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZMQOrCj7exXxV7NmCiorW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZMQOrCj7exXxV7NmCiorW',
#   'duration_ms': 274973,
#   'time_signature': 4},
#  {'danceability': 0.225,
#   'energy': 0.778,
#   'key': 3,
#   'loudness': -7.249,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000325,
#   'instrumentalness': 0.0416,
#   'liveness': 0.209,
#   'valence': 0.413,
#   'tempo': 147.303,
#   'type': 'audio_features',
#   'id': '7sTfLbRGZ74dbVVYfNc8Kk',
#   'uri': 'spotify:track:7sTfLbRGZ74dbVVYfNc8Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sTfLbRGZ74dbVVYfNc8Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sTfLbRGZ74dbVVYfNc8Kk',
#   'duration_ms': 274973,
#   'time_signature': 4}]
